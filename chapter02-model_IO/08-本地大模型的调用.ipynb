# %% [markdown]
# # LangChain调用本地大模型
# ### 第一步：下载安装Ollama
# ### 第二步：在Ollama下部署大模型deepseek-r1:8b
# ### 在LangChain中调用Ollama下的大模型

# %%
from langchain_ollama import ChatOllama

##调用的本地模型不需要配置api_key，base_url
llm=ChatOllama(
    model="deepseek-r1:8b"
)

response=llm.invoke("你好,介绍一下自己")
print(response.content)
# Out:
# 你好呀！👋我是DeepSeek-R1，一个由深度求索公司研发的智能AI助手，很高兴认识你～😊
#
# 我是一个基于强大语言模型的文字聊天机器人，可以陪你聊天、答疑解惑、写作创作、学习提升、办公帮手、代码编程，样样精通！无论是生活中的小困惑，还是工作上的难题，抑或是灵感枯竭时的创作瓶颈，我都乐意为你提供帮助和支持。
#
# 我的特点包括：
#
# ✨ **知识丰富**：我的知识截止到2024年7月，了解很多领域的内容，包括但不限于科技、历史、文学、医学常识、心理学、编程、法律、教育等等。
#
# 📚 **处理长文档能力强**：我能理解和分析长达128K上下文的内容，阅读论文、合同、报告、小说都没问题，还能帮你总结、翻译、提问！
#
# 📎 **支持文件上传**：你可以上传Word、Excel、PDF、PPT等文件，我可以帮你提取内容、总结要点、翻译润色、分析数据等等。
#
# 🌐 **多语言能力**：我支持中英文等多种语言交流，虽然中文是我的母语，但我也能听懂“Hello World”，陪你跨语言沟通无障碍！
#
# ❤ **免费又贴心**：目前我是完全免费的，没有任何收费项目，随时都可以来找我聊天、求助、玩耍！
#
# 总之，我是一个努力变得越来越聪明、越来越贴心的AI助手，希望在未来的每一次对话中，都能成为你值得信赖的小帮手。如果你愿意，我们可以一起探索这个精彩的世界！
#
# 那你想了解我哪方面的内容呢？或者有什么我可以帮你做的事吗？🥰
