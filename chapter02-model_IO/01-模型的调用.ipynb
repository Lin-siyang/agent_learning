# %% [markdown]
# 1、非对话模型（OpenAI)

# %% [markdown]
# 2、Chat Models（聊天模型）
# 输入：接受消息列表LIST[BaseMessage],或PromptValue,每条消息需要指定角色（如SystemMessage,HumanMessage,AIMessage）
# 输出：返回代角色的消息对象（AIMessage)

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage,HumanMessage

chat_model = ChatOpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com",
    temperature=0,
    model="deepseek-chat",
)
messages=[
    SystemMessage(content="你是一个古诗达人"),
    HumanMessage(content="写一首四句情诗")
]
#接受消息列表LIST[]
response = chat_model.invoke(messages)
print(type(response))     #<class 'langchain_core.messages.ai.AIMessage'>
print(response)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# content='《无题》\n一寸相思一寸灰，为君憔悴为君痴。\n此情可待成追忆，只是当时已惘然。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 14, 'total_tokens': 44, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 14}, 'model_provider': 'openai', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache_new_kvcache', 'id': '5ef1f9b8-4308-4659-84e4-ac6617345e71', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6ce0-7c3b-7351-947c-8329833cc541-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 14, 'output_tokens': 30, 'total_tokens': 44, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}

# %% [markdown]
# # 调用对话模型
# ## 使用配置文件的方法.env

# %%
import os
import dotenv
# 加载配置文件
dotenv.load_dotenv()
chat_model = ChatOpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
    temperature=0,
    model="deepseek-chat",
)
messages=[
    HumanMessage(content="你好")
]
response = chat_model.invoke(messages)
print(response.content)
# Out:
# <class 'list'>

# %% [markdown]
# # 使用各个平台的API调用大模型
# ## OpenAI 非对话模型

# %%
import os
from openai import OpenAI
import os
import dotenv
dotenv.load_dotenv()
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL")
)
response = client.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt="写一首五句情诗",
    max_tokens=100,
    temperature=0.7,
)

print(response.choices[0].text.strip())
# Out:
# 你是我心中的那朵花，
# 绽放着美丽的笑颜，
# 无论春夏秋冬，
# 永远不会枯萎凋零，
# 你是我爱的永恒。

# %% [markdown]
# ## 调用对话模型
# ### 1、closeapi  2、阿里云百炼平台

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url="https://api.openai-proxy.org/v1"
)
# 调用对话模型使用.chat.completions.create()
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "你是一个古诗达人"},
        {"role": "user", "content": "写一首四句情诗"}
    ],
    max_tokens=100,
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# 繁花落尽叶飘零，思念如潮涌心头。
# 寂寞夜色如水深，只盼你在我身旁。
